# %%
import config
import os
import pandas as pd
from matplotlib import pyplot as plt

# %%
from vis_utils import vis_layer_loss_accuracy
vis_layer_loss_accuracy()

# %%
folder_path = config.RESULTS
files = os.listdir(folder_path)
file_paths = [os.path.join(folder_path, file) for file in files if file.endswith('.csv') and file.startswith('5')]

# %%
file_paths
# Out:
# ['/home/owais/hyperparameter-effects-ocr/Results/5_7.csv',
#  '/home/owais/hyperparameter-effects-ocr/Results/5_2.csv',
#  '/home/owais/hyperparameter-effects-ocr/Results/5_9.csv',
#  '/home/owais/hyperparameter-effects-ocr/Results/5_4.csv',
#  '/home/owais/hyperparameter-effects-ocr/Results/5_3.csv',
#  '/home/owais/hyperparameter-effects-ocr/Results/5_1.csv',
#  '/home/owais/hyperparameter-effects-ocr/Results/5_5.csv']

# %%
for file in file_paths:
        filter = file.split('/')[-1].split('.')[0].split('_')[1]
        #names.append(filter)
        data = pd.read_csv(file)
        print(data.shape)
# Out:
# (5, 5)
# (7, 5)
# (12, 5)
# (11, 5)
# (8, 5)
# (6, 5)
# (12, 5)
